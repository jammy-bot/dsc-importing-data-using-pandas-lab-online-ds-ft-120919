# %% [markdown]
# # Importing Data Using Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll get some practice with loading files with summary or metadata, and if you find that easy, the optional "level up" content covers loading data from a corrupted csv file!
#
# ## Objectives
# You will be able to:
#
# - Use pandas to import data from a CSV and and an Excel spreadsheet
#
# ##  Loading Files with Summary or Meta Data
#
# Load either of the files `'Zipcode_Demos.csv'` or `'Zipcode_Demos.xlsx'`. What's going on with this dataset? Clean it up into a useable format and describe the nuances of how the data is currently formatted.
#
# All data files are stored in a folder titled `'Data'`.

# %%
# Import pandas using the standard alias
import pandas as pd

# %%
# Import the file and print the first 5 rows
df = pd.read_csv('Data/Zipcode_Demos.csv')
df.head()
# Out:
#    0  Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  1                 NaN          0        NaN        NaN        NaN
# 1  2   JURISDICTION NAME    10005.8        NaN        NaN        NaN
# 2  3  COUNT PARTICIPANTS        9.4        NaN        NaN        NaN
# 3  4        COUNT FEMALE        4.8        NaN        NaN        NaN
# 4  5      PERCENT FEMALE      0.404        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 37 Unnamed: 38  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#   Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 45 Unnamed: 46
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 47 columns]

# %%
# Print the last 5 rows of df
df.tail()
# Out:
#      0 Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 52  53              10006          6          2       0.33          4
# 53  54              10007          1          0          0          1
# 54  55              10009          2          0          0          2
# 55  56              10010          0          0          0          0
# 56  57              10011          3          2       0.67          1
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 37 Unnamed: 38  \
# 52       0.67          0          0          6  ...           6         100
# 53          1          0          0          1  ...           1         100
# 54          1          0          0          2  ...           2         100
# 55          0          0          0          0  ...           0           0
# 56       0.33          0          0          3  ...           3         100
#
#    Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# 52           0           0           6           1           0           0
# 53           1           1           0           0           0           0
# 54           0           0           2           1           0           0
# 55           0           0           0           0           0           0
# 56           0           0           3           1           0           0
#
#    Unnamed: 45 Unnamed: 46
# 52           6         100
# 53           1         100
# 54           2         100
# 55           0           0
# 56           3         100
#
# [5 rows x 47 columns]

# %%
# What is going on with this data set? Anything unusual?

'''
The second and third columns are statistical data.
Header and data are much further down in the dataframe.
'''
# Out:
# '\nThe second and third columns are statistical data.\nHeader and data are much further down in the dataframe.\n'

# %%
# Clean up the dataset
df1 = pd.read_csv('Data/Zipcode_Demos.csv', skiprows=[1], nrows=45, usecols=[0, 1,2])
df1.head()
# Out:
#    0  Average Statistics  Unnamed: 2
# 0  2   JURISDICTION NAME   10005.800
# 1  3  COUNT PARTICIPANTS       9.400
# 2  4        COUNT FEMALE       4.800
# 3  5      PERCENT FEMALE       0.404
# 4  6          COUNT MALE       4.600

# %%
# Clean up the dataset
df2 = pd.read_csv('Data/Zipcode_Demos.csv', header=47)
df2.head()
# Out:
#    47  JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0  48              10001                  44            22            0.50
# 1  49              10002                  35            19            0.54
# 2  50              10003                   1             1            1.00
# 3  51              10004                   0             0            0.00
# 4  52              10005                   2             2            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          16          0.46                     0                       0
# 2           0          0.00                     0                       0
# 3           0          0.00                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# 0                  44  ...                          44
# 1                  35  ...                          35
# 2                   1  ...                           1
# 3                   0  ...                           0
# 4                   2  ...                           2
#
#    PERCENT CITIZEN STATUS TOTAL  COUNT RECEIVES PUBLIC ASSISTANCE  \
# 0                           100                                20
# 1                           100                                 2
# 2                           100                                 0
# 3                             0                                 0
# 4                           100                                 0
#
#    PERCENT RECEIVES PUBLIC ASSISTANCE  COUNT NRECEIVES PUBLIC ASSISTANCE  \
# 0                                0.45                                 24
# 1                                0.06                                 33
# 2                                0.00                                  1
# 3                                0.00                                  0
# 4                                0.00                                  2
#
#    PERCENT NRECEIVES PUBLIC ASSISTANCE  COUNT PUBLIC ASSISTANCE UNKNOWN  \
# 0                                 0.55                                0
# 1                                 0.94                                0
# 2                                 1.00                                0
# 3                                 0.00                                0
# 4                                 1.00                                0
#
#    PERCENT PUBLIC ASSISTANCE UNKNOWN  COUNT PUBLIC ASSISTANCE TOTAL  \
# 0                                  0                             44
# 1                                  0                             35
# 2                                  0                              1
# 3                                  0                              0
# 4                                  0                              2
#
#    PERCENT PUBLIC ASSISTANCE TOTAL
# 0                              100
# 1                              100
# 2                              100
# 3                                0
# 4                              100
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Level Up (Optional) - Loading Corrupt CSV files
#
# Occasionally, you encounter some really ill-formatted data. One example of this can be data that has strings containing commas in a csv file. Under the standard protocol, when this occurs, one is supposed to use quotes to differentiate between the commas denoting fields and the commas within those fields themselves. For example, we could have a table like this:
#
# `ReviewerID,Rating,N_reviews,Review,VenueID
# 123456,4,137,This restaurant was pretty good, we had a great time.,98765`
#
# Which should be saved like this if it were a csv (to avoid confusion with the commas in the Review text):
# `"ReviewerID","Rating","N_reviews","Review","VenueID"
# "123456","4","137","This restaurant was pretty good, we had a great time.","98765"`
#
# Attempt to import the corrupt file, or at least a small preview of it. It is appropriately titled `'Yelp_Reviews_corrupt.csv'`. Investigate some of the intricacies of skipping rows to then pass over this error and comment on what you think is going on.

# %%
# Hint: Here's a useful programming pattern to use
try:
    # yelp_df.drop(2330, axis=0)
    # yelp_df.shape
    # skiprows=1, nrows=100
    # skiprows=50, nrows=10
    # skiprows=40, nrows=10
    # skiprows=41, nrows=10
    
except Exception as e:
    # Handle your exception e
    # (200, 10)
# Out:
#   File "<ipython-input-7-bafd7cc1c54d>", line 10
#     except Exception as e:
#          ^
# IndentationError: expected an indented block

# %%
yelp_df = pd.read_csv('Data/Yelp_Reviews_corrupt.csv', skiprows=41, nrows=10)
yelp_df.head(10)
yelp_df.tail(10)
# Out:
#                                                                    Do yourself and your wallet a favour and avoid it!  \
# 179 YPa8t1631tlRQms0p331ZQ 0 2016-04-10 0 vCwlUF30mV7Eg5MCS3N39Q 4  What a nice and friendly person that answered ...
# 180 eZCE1u_3ORlX8dHSVTjl9w 0 2016-03-10 1 GuD3Og1PmJCqXAiWQe1xew 4  I have been here 3 1/2 years.   The staff is a...
# 182 ruWTngdiC68O9la27hvvHw 0 2016-02-24 0 Tifm4ETlt4FXiuGwhq__lg 4  This place is not just a restaurant has a grea...
# 183 7KkgMcbVaetryW1wwpzvvA 0 2016-02-29 0 htV6dNmUqaXwCIRt7vfO5A 4  It great fast food and get large portions. It ...
# 184 bvGdqJ-SeGdIHX-HEabwlg 0 2016-05-29 0 AR_IDHl2P4kUVPB_tTsA6w 4  I went there a couple week ago. The service wa...
# 185 h1Jq1YlqPyD1mGSW0sjRaQ 0 2016-03-07 0 JL6B_spdwG_gLMEdh4Z-Mg 1  I call them to switch to their service for bot...
# 186 9tLCuUmw3Tlco-tKPGkIWQ 1 2016-03-25 0 vPA9ZwuatQhnfu6WrG0mpw 5  Great fast food restaurant large portions. The...
# 188 ICw43H7hrbSuXTjDBmJxbA 1 2016-02-29 0 RUoRwBWiYAZ7FhRMg_ibZA 5  I was just at their new store on Cheyenne on S...
# 189 _pBXtjN43eqMV0XZTz7nmw 0 2016-03-25 0 ohzlH9CWRuP8TehyfTUp6g 4  Its a nice club open air with swimming pools t...
# 190 3kdSl5mo9dWC4clrQjEDGg 0 2015-10-17 1 Bay72mIfR-yGKZf_S9xQeg 4               ????????????????????????????????????
#
#                                                                       0  \
# 179 YPa8t1631tlRQms0p331ZQ 0 2016-04-10 0 vCwlUF30mV7Eg5MCS3N39Q 4  1.0
# 180 eZCE1u_3ORlX8dHSVTjl9w 0 2016-03-10 1 GuD3Og1PmJCqXAiWQe1xew 4  4.0
# 182 ruWTngdiC68O9la27hvvHw 0 2016-02-24 0 Tifm4ETlt4FXiuGwhq__lg 4  1.0
# 183 7KkgMcbVaetryW1wwpzvvA 0 2016-02-29 0 htV6dNmUqaXwCIRt7vfO5A 4  0.0
# 184 bvGdqJ-SeGdIHX-HEabwlg 0 2016-05-29 0 AR_IDHl2P4kUVPB_tTsA6w 4  0.0
# 185 h1Jq1YlqPyD1mGSW0sjRaQ 0 2016-03-07 0 JL6B_spdwG_gLMEdh4Z-Mg 1  0.0
# 186 9tLCuUmw3Tlco-tKPGkIWQ 1 2016-03-25 0 vPA9ZwuatQhnfu6WrG0mpw 5  1.0
# 188 ICw43H7hrbSuXTjDBmJxbA 1 2016-02-29 0 RUoRwBWiYAZ7FhRMg_ibZA 5  1.0
# 189 _pBXtjN43eqMV0XZTz7nmw 0 2016-03-25 0 ohzlH9CWRuP8TehyfTUp6g 4  0.0
# 190 3kdSl5mo9dWC4clrQjEDGg 0 2015-10-17 1 Bay72mIfR-yGKZf_S9xQeg 4  NaN
#
#                                                                     YHWsLBS8jzZiPjKHMFOaAA
# 179 YPa8t1631tlRQms0p331ZQ 0 2016-04-10 0 vCwlUF30mV7Eg5MCS3N39Q 4  wMttR-7frrO-YzDsIiA4GQ
# 180 eZCE1u_3ORlX8dHSVTjl9w 0 2016-03-10 1 GuD3Og1PmJCqXAiWQe1xew 4  wMttR-7frrO-YzDsIiA4GQ
# 182 ruWTngdiC68O9la27hvvHw 0 2016-02-24 0 Tifm4ETlt4FXiuGwhq__lg 4  dQzQ4bN0Rnb8M-0LqTl3-g
# 183 7KkgMcbVaetryW1wwpzvvA 0 2016-02-29 0 htV6dNmUqaXwCIRt7vfO5A 4  dQzQ4bN0Rnb8M-0LqTl3-g
# 184 bvGdqJ-SeGdIHX-HEabwlg 0 2016-05-29 0 AR_IDHl2P4kUVPB_tTsA6w 4  dQzQ4bN0Rnb8M-0LqTl3-g
# 185 h1Jq1YlqPyD1mGSW0sjRaQ 0 2016-03-07 0 JL6B_spdwG_gLMEdh4Z-Mg 1  dQzQ4bN0Rnb8M-0LqTl3-g
# 186 9tLCuUmw3Tlco-tKPGkIWQ 1 2016-03-25 0 vPA9ZwuatQhnfu6WrG0mpw 5  dQzQ4bN0Rnb8M-0LqTl3-g
# 188 ICw43H7hrbSuXTjDBmJxbA 1 2016-02-29 0 RUoRwBWiYAZ7FhRMg_ibZA 5  dQzQ4bN0Rnb8M-0LqTl3-g
# 189 _pBXtjN43eqMV0XZTz7nmw 0 2016-03-25 0 ohzlH9CWRuP8TehyfTUp6g 4  dQzQ4bN0Rnb8M-0LqTl3-g
# 190 3kdSl5mo9dWC4clrQjEDGg 0 2015-10-17 1 Bay72mIfR-yGKZf_S9xQeg 4                     NaN

# %% [markdown]
# ## Summary
#
# Congratulations, you now practiced your Pandas-importing skills!
